# %%
from classifier_manager import *
from dataset_manager import *
from metrics import *
import matplotlib.pyplot as plt
from roc_pr_tools import *
from plot_tools import *

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plotAllAgainstDataset(name):
    X_train, X_test, y_train, y_test = split_dataset(get_dataset(name))
    for classifier_name in classifier_names:
        print('Classifier: ', classifier_name)

        classifier = get_classifier(classifier_name)
        fit_classifier(classifier, X_train, y_train)

        output = predict_classifier(classifier, X_test)

        fpr, tpr = get_roc_curve(output, y_test)
        print("Area under ROC curve: ", get_auc(fpr, tpr))

        recalls, precisions = get_pr_curve(output, y_test)
        print("Area under PR curve: ", get_auc(recalls, precisions ))

        showPlots([{'data': tpr, 'x': fpr, 'label': "ROC"},
                   {'data': precisions, 'x': recalls, 'label': "PR"}])

        show_plot()

# %%
plt.rcParams['figure.figsize'] = [9, 6]
plt.rcParams['figure.dpi'] = 100

plotAllAgainstDataset("linear")
# Out:
# Classifier:  Nearest Neighbors
# Area under ROC curve:  0.8565072302558397
# Area under PR curve:  0.4984702242500257
# Classifier:  Linear SVM
# Area under ROC curve:  0.8829254727474972
# Area under PR curve:  0.8662616443989388
# Classifier:  RBF SVM
# Area under ROC curve:  0.8359288097886541
# Area under PR curve:  0.752120842006025
# Classifier:  Gaussian Process
# Area under ROC curve:  0.8979421579532816
# Area under PR curve:  0.8852298141171286
# Classifier:  Decision Tree
# Area under ROC curve:  0.8669354838709677
# Area under PR curve:  0.5406683211749321
# Classifier:  Random Forest
# Area under ROC curve:  0.9041991101223583
# Area under PR curve:  0.8742043447092334
# Classifier:  Neural Net
# Area under ROC curve:  0.8934927697441601
# Area under PR curve:  0.881009589197115
# Classifier:  AdaBoost
# Area under ROC curve:  0.8958565072302559
# Area under PR curve:  0.8499701146835985
# Classifier:  Naive Bayes
# Area under ROC curve:  0.8923804226918799
# Area under PR curve:  0.8814029835323116
# Classifier:  QDA
# Area under ROC curve:  0.9010011123470523
# Area under PR curve:  0.8907986271716992
